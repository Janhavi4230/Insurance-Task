# %% [markdown]
# <a href="https://colab.research.google.com/github/Janhavi4230/Insurance-Task/blob/main/Insurance_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-065d2204-33de-45b0-9c2f-9a77e27c686c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-065d2204-33de-45b0-9c2f-9a77e27c686c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath='/content/insurance.csv'
df=pd.read_csv(filepath)

# %%
df.head(10)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59
# 7   37  female  27.7         3     no  northwest   7281.51
# 8   37    male  29.8         2     no  northeast   6406.41
# 9   60  female  25.8         0     no  northwest  28923.14

# %%
df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  expenses
# 0     False  False  False     False   False   False     False
# 1     False  False  False     False   False   False     False
# 2     False  False  False     False   False   False     False
# 3     False  False  False     False   False   False     False
# 4     False  False  False     False   False   False     False
# ...     ...    ...    ...       ...     ...     ...       ...
# 1333  False  False  False     False   False   False     False
# 1334  False  False  False     False   False   False     False
# 1335  False  False  False     False   False   False     False
# 1336  False  False  False     False   False   False     False
# 1337  False  False  False     False   False   False     False
#
# [1338 rows x 7 columns]

# %%
df.sum
# Out:
# <bound method DataFrame.sum of       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]>

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.min()
# Out:
# age                18
# sex            female
# bmi              16.0
# children            0
# smoker             no
# region      northeast
# expenses      1121.87
# dtype: object

# %%
df.max()
# Out:
# age                64
# sex              male
# bmi              53.1
# children            5
# smoker            yes
# region      southwest
# expenses     63770.43
# dtype: object

# %%
df.mean
# Out:
# <bound method DataFrame.mean of       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]>

# %%
df.value_counts()
# Out:
# age  sex     bmi   children  smoker  region     expenses
# 19   male    30.6  0         no      northwest  1639.56     2
# 48   female  25.9  3         yes     southeast  24180.93    1
#              22.8  0         no      southwest  8269.04     1
# 47   male    47.5  1         no      southeast  8083.92     1
#              38.9  2         yes     southeast  44202.65    1
#                                                            ..
# 30   male    44.2  2         no      southeast  4266.17     1
#              38.8  1         no      southeast  18963.17    1
#              37.8  2         yes     southwest  39241.44    1
#              37.4  3         no      northeast  5428.73     1
# 31   female  29.3  1         no      southeast  4350.51     1
# Name: count, Length: 1337, dtype: int64

# %%
df.count()
# Out:
# age         1338
# sex         1338
# bmi         1338
# children    1338
# smoker      1338
# region      1338
# expenses    1338
# dtype: int64

# %%
df.sample()
# Out:
#      age   sex   bmi  children smoker     region  expenses
# 948   42  male  31.3         0     no  northwest   6358.78

# %%
df.nunique()
# Out:
# age           47
# sex            2
# bmi          275
# children       6
# smoker         2
# region         4
# expenses    1337
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1337 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y)
plt.show()

# %%
# Scatter Plot

# %%
#Age  vs Expenses

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["age"], df["expenses"], color="orange")
plt.title("Age vs Insurance Expenses")
plt.xlabel("Age")
plt.ylabel("Expenses")
plt.show()

# %%
# BMI vs Expenses

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["bmi"], df["expenses"], color="purple")
plt.title("BMI vs Insurance Expenses")
plt.xlabel("BMI")
plt.ylabel("Expenses")
plt.show()

# %%
# Region vs Expenses

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["region"], df["expenses"], color="orange")
plt.title("Region vs Expenses")
plt.xlabel("Region")
plt.ylabel("Expenses")
plt.show()

# %%
# Countplot

# %%
# Smokker vs Age

# %%
sns.countplot(x="smoker", hue="age" ,data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
# Sex vs Children

# %%
sns.countplot(x="sex", hue="children" ,data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Histogram

# %%
# Age Distribution

# %%
plt.figure(figsize=(8,5))
plt.hist(df["age"], bins=10, color="skyblue", edgecolor="black")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# Sex Distribution

# %%
plt.figure(figsize=(8,5))
plt.hist(df["sex"], bins=10, color="skyblue", edgecolor="black")
plt.title("Sex Distribution")
plt.xlabel("Sex")
plt.ylabel("Frequency")
plt.show()

# %%
# BMI Distribution

# %%
plt.figure(figsize=(6,4))
plt.hist(df['bmi'], bins=15, color='green', edgecolor='black')
plt.title("BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar Chart

# %%
# Average Expenses by Region

# %%
avg_expenses = df.groupby("region")["expenses"].mean()

plt.figure(figsize=(8,5))
plt.bar(avg_expenses.index, avg_expenses.values, color="orange")
plt.title("Average Insurance Expenses by Region")
plt.xlabel("Region")
plt.ylabel("Average Expenses")
plt.show()

# %%
# Gender Distribution

# %%
gender = df['sex'].value_counts()
plt.figure(figsize=(4,3))
plt.bar(gender.index, gender.values, color=['blue', 'pink'])
plt.title("Gender Distribution")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# %%
# Children Count

# %%
children = df['children'].value_counts().sort_index()
plt.figure(figsize=(6,4))
plt.bar(children.index, children.values, color='orange')
plt.title("Number of Children")
plt.xlabel("Children")
plt.ylabel("Count")
plt.show()

# %%
# Average Expenses by Smoker

# %%
avg = df.groupby('smoker')['expenses'].mean()

plt.figure(figsize=(5,4))
plt.bar(avg.index, avg.values, color=['green', 'red'])
plt.title("Average Expenses by Smoker")
plt.xlabel("Smoker")
plt.ylabel("Average Expenses")
plt.show()

# %%
# Pie Chart

# %%
# Smoker Distribution

# %%
smoker_counts = df["smoker"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(
    smoker_counts,
    labels=smoker_counts.index,
    autopct="%1.1f%%",
    startangle=90)
plt.title("Smoker Distribution")
plt.show()

# %%
# Region Distribution

# %%
region_counts = df["region"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(
    region_counts,
    labels=region_counts.index,
    autopct="%1.1f%%",
    startangle=90)
plt.title("Region Distribution")
plt.show()

# %%
import seaborn as sns

# %%
# Heatmap

# %%
corr = df.select_dtypes(include=['number']).corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
corr = df.select_dtypes(include=['number']).corr()
sns.heatmap(corr,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
# Regression line

# %%
X = df[['bmi']]
y = df['expenses']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.figure(figsize=(8,5))
plt.scatter(X, y, color='green')
plt.plot(X, y_pred, color='red', linewidth=2)

plt.title("Linear Regression: BMI vs Expenses")
plt.xlabel("BMI")
plt.ylabel("Expenses")
plt.grid(True)

plt.show()

print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
print("R² Score:", model.score(X, y))
# Out:
# Slope: 394.32764383971147
# Intercept: 1178.17954573924
# R² Score: 0.03943252905734407

# %%
X = df[['age']]
y = df['expenses']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.figure(figsize=(8,5))
plt.scatter(X, y, color='green')
plt.plot(X, y_pred, color='red', linewidth=2)

plt.title("Linear Regression: Age vs Expenses")
plt.xlabel("Age")
plt.ylabel("Expenses")
plt.grid(True)

plt.show()

print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
print("R² Score:", model.score(X, y))
# Out:
# Slope: 257.7226178298078
# Intercept: 3165.8851877923116
# R² Score: 0.08940589905359309
